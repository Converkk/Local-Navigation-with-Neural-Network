# %%
import numpy as np


from google.colab import drive
drive.mount('/content/drive')

#Results =  np.load('/content/drive/My Drive/experiments/Results.npy')
Results =  np.load('/content/drive/My Drive/exper_1/Results_3.npy')


one_results = 255*Results[int(1389/13)*14]


one_results = one_results.reshape((100, 100))

# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

#  Двумерный массив пикселей:

fig, ax = plt.subplots()

ax.imshow(one_results)

fig.set_figwidth(6)    #  ширина и
fig.set_figheight(6)    #  высота "Figure"

plt.show()
# Out:
# Mounted at /content/drive

# %%
Results.shape
# Out:
# (628, 10000)

# %%
import imageio
imageio.imwrite('/content/drive/My Drive/Experiments/test_results14.jpg', one_results)
# Out:
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.06961293518543243, 208.25442504882812]. Convert image to uint8 prior to saving to suppress this warning.

# %%
import numpy as np


from google.colab import drive
drive.mount('/content/drive')

Results =  np.load('/content/drive/My Drive/Glubins/Results.npy')
#Results =  np.load('/content/drive/My Drive/Glubins/Results_3.npy')


one_results_1 = 255*Results[259]


one_results_1 = one_results_1.reshape((100, 100))

# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

#  Двумерный массив пикселей:

fig, ax = plt.subplots()

ax.imshow(one_results_1)

fig.set_figwidth(6)    #  ширина и
fig.set_figheight(6)    #  высота "Figure"

plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
if (one_results == one_results_1).all():
  print('True')
else:
  print('False')
# Out:
# False

# %%
import numpy as np
from sklearn.utils import shuffle

a = np.array([1, 2, 3, 4, 5])
b = np.array([66, 77, 88, 99, 100])
c = np.array([9, 9, 9, 9, 9])

a, b = shuffle(a, b, c)

print(a, b, c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-6f485ebfffd3> in <module>()
#       6 c = np.array([9, 9, 9, 9, 9])
#       7
# ----> 8 a, b = shuffle(a, b, c)
#       9
#      10 print(a, b, c)
#
# ValueError: too many values to unpack (expected 2)
